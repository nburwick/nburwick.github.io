# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Identify Today's Date
today = pd.to_datetime('today').normalize().strftime("%m-%d-%Y")
print(f"Today is: {today}")

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Today is: 03-04-2023
# Number of cities in the list: 615

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
api_key = weather_api_key
units = "imperial"

# Define Empty Data Frame to store city data
city_data_df = pd.DataFrame(columns=['City', 'Lat', 'Lng', 'Max Temp','Humidity', 'Cloudiness',
                                     'Wind Speed', 'Country', 'Date'])

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    time.sleep(1)    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_data = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_data['coord']['lat']
        city_lng = city_data['coord']['lon']
        city_max_temp = city_data['main']['temp_max']
        city_humidity = city_data['main']['humidity']
        city_clouds = city_data['clouds']['all']
        city_wind = city_data['wind']['speed']
        city_country = city_data['sys']['country']
        city_date = city_data['dt']

        # Append the City Data into city_data_df
        temp_df = pd.DataFrame({  "City": city, 
                                  "Lat": city_lat, 
                                  "Lng": city_lng, 
                                  "Max Temp": city_max_temp,
                                  "Humidity": city_humidity,
                                  "Cloudiness": city_clouds,
                                  "Wind Speed": city_wind,
                                  "Country": city_country,
                                  "Date": city_date},
                                                     index=[0])

        city_data_df = pd.concat([city_data_df, temp_df], axis=0,ignore_index=True)
        
    except:
        print("City not found. Skipping...")
        pass
        
        
# Indicate that Data Loading is complete 
print("-----------------------------")
print(f"Data Retrieval Complete: Found {len(city_data_df)} Cities")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | mehamn
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | candawaga
# City not found. Skipping...
# Processing Record 5 of Set 1 | birao
# Processing Record 6 of Set 1 | dallas
# Processing Record 7 of Set 1 | port hardy
# Processing Record 8 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 1 | poum
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | aasiaat
# Processing Record 12 of Set 1 | broken hill
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | tautira
# Processing Record 17 of Set 1 | thunder bay
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | namibe
# Processing Record 20 of Set 1 | kondopoga
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | ambon
# Processing Record 23 of Set 1 | buncrana
# Processing Record 24 of Set 1 | channel-port aux basques
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | sheksna
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | grand-lahou
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | severo-kurilsk
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | bubaque
# Processing Record 36 of Set 1 | westport
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | achisay
# City not found. Skipping...
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | tommot
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | saquarema
# Processing Record 48 of Set 1 | bathsheba
# Processing Record 49 of Set 1 | imbituba
# Processing Record 50 of Set 1 | leningradskiy
# Processing Record 0 of Set 2 | padang
# Processing Record 1 of Set 2 | mecca
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | hasaki
# Processing Record 5 of Set 2 | nadym
# Processing Record 6 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 2 | qaqortoq
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | guerrero negro
# Processing Record 10 of Set 2 | talnakh
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 2 | saldanha
# Processing Record 14 of Set 2 | vryburg
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | inta
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | lagoa
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | touros
# Processing Record 21 of Set 2 | nathdwara
# Processing Record 22 of Set 2 | sawtell
# Processing Record 23 of Set 2 | fortuna
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 2 | nizhneangarsk
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | talcahuano
# Processing Record 30 of Set 2 | wamba
# Processing Record 31 of Set 2 | derac
# Processing Record 32 of Set 2 | santander
# Processing Record 33 of Set 2 | salalah
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | yellandu
# Processing Record 40 of Set 2 | luderitz
# Processing Record 41 of Set 2 | chuy
# Processing Record 42 of Set 2 | raudeberg
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | murray bridge
# Processing Record 45 of Set 2 | vila velha
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | vredendal
# Processing Record 49 of Set 2 | alofi
# Processing Record 0 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 3 | dingzhou
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | maceio
# Processing Record 4 of Set 3 | kavaratti
# Processing Record 5 of Set 3 | pevek
# Processing Record 6 of Set 3 | natal
# Processing Record 7 of Set 3 | togur
# Processing Record 8 of Set 3 | cuamba
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | husavik
# Processing Record 13 of Set 3 | miraflores
# Processing Record 14 of Set 3 | okhotsk
# Processing Record 15 of Set 3 | hobart
# Processing Record 16 of Set 3 | manavalakurichi
# Processing Record 17 of Set 3 | vanimo
# Processing Record 18 of Set 3 | lavrentiya
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | deputatskiy
# Processing Record 21 of Set 3 | asau
# Processing Record 22 of Set 3 | athabasca
# Processing Record 23 of Set 3 | flinders
# Processing Record 24 of Set 3 | kruisfontein
# Processing Record 25 of Set 3 | kununurra
# Processing Record 26 of Set 3 | valparaiso
# Processing Record 27 of Set 3 | gazanjyk
# Processing Record 28 of Set 3 | tual
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | thompson
# Processing Record 31 of Set 3 | pangnirtung
# Processing Record 32 of Set 3 | bokoro
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | torbay
# Processing Record 35 of Set 3 | pisco
# Processing Record 36 of Set 3 | asfi
# Processing Record 37 of Set 3 | lata
# Processing Record 38 of Set 3 | abha
# Processing Record 39 of Set 3 | greenville
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 3 | lethem
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 3 | sitka
# Processing Record 46 of Set 3 | dingle
# Processing Record 47 of Set 3 | lazaro cardenas
# Processing Record 48 of Set 3 | albany
# Processing Record 49 of Set 3 | manokwari
# Processing Record 0 of Set 4 | filingue
# Processing Record 1 of Set 4 | saint anthony
# Processing Record 2 of Set 4 | gamba
# Processing Record 3 of Set 4 | alta floresta
# Processing Record 4 of Set 4 | saint-augustin
# Processing Record 5 of Set 4 | osakarovka
# Processing Record 6 of Set 4 | yokadouma
# Processing Record 7 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 8 of Set 4 | nabire
# Processing Record 9 of Set 4 | vila franca do campo
# Processing Record 10 of Set 4 | katsuura
# Processing Record 11 of Set 4 | yablonovo
# Processing Record 12 of Set 4 | sapa
# Processing Record 13 of Set 4 | kerman
# Processing Record 14 of Set 4 | vila do maio
# Processing Record 15 of Set 4 | jingdezhen
# Processing Record 16 of Set 4 | mubi
# Processing Record 17 of Set 4 | bhabua
# Processing Record 18 of Set 4 | emerald
# Processing Record 19 of Set 4 | longyearbyen
# Processing Record 20 of Set 4 | lasa
# Processing Record 21 of Set 4 | olafsvik
# Processing Record 22 of Set 4 | porto novo
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | nam tha
# City not found. Skipping...
# Processing Record 25 of Set 4 | cherskiy
# Processing Record 26 of Set 4 | atar
# Processing Record 27 of Set 4 | yerbogachen
# Processing Record 28 of Set 4 | praia
# Processing Record 29 of Set 4 | polis
# Processing Record 30 of Set 4 | vardo
# Processing Record 31 of Set 4 | solnechnyy
# Processing Record 32 of Set 4 | lompoc
# Processing Record 33 of Set 4 | cavan
# Processing Record 34 of Set 4 | samarai
# Processing Record 35 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 4 | monrovia
# Processing Record 37 of Set 4 | tilichiki
# Processing Record 38 of Set 4 | ust-nera
# Processing Record 39 of Set 4 | swift current
# Processing Record 40 of Set 4 | port lincoln
# Processing Record 41 of Set 4 | huayang
# Processing Record 42 of Set 4 | diamantino
# Processing Record 43 of Set 4 | coahuayana
# Processing Record 44 of Set 4 | marawi
# Processing Record 45 of Set 4 | tierralta
# Processing Record 46 of Set 4 | paamiut
# Processing Record 47 of Set 4 | taltal
# Processing Record 48 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 49 of Set 4 | nome
# Processing Record 0 of Set 5 | nuuk
# Processing Record 1 of Set 5 | denizli
# Processing Record 2 of Set 5 | gizo
# Processing Record 3 of Set 5 | mandan
# Processing Record 4 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 5 of Set 5 | saint george
# Processing Record 6 of Set 5 | andria
# Processing Record 7 of Set 5 | kurumkan
# Processing Record 8 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 5 | codrington
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | esmeraldas
# Processing Record 12 of Set 5 | sola
# Processing Record 13 of Set 5 | faya
# Processing Record 14 of Set 5 | buraydah
# Processing Record 15 of Set 5 | mayo
# Processing Record 16 of Set 5 | otorohanga
# Processing Record 17 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 5 | kenai
# Processing Record 19 of Set 5 | rorvik
# Processing Record 20 of Set 5 | rudbar
# Processing Record 21 of Set 5 | lebu
# Processing Record 22 of Set 5 | tateyama
# Processing Record 23 of Set 5 | kiruna
# Processing Record 24 of Set 5 | chum phae
# Processing Record 25 of Set 5 | churapcha
# Processing Record 26 of Set 5 | oranjestad
# Processing Record 27 of Set 5 | puliyur
# Processing Record 28 of Set 5 | zastron
# Processing Record 29 of Set 5 | viedma
# Processing Record 30 of Set 5 | constitucion
# Processing Record 31 of Set 5 | sitrah
# Processing Record 32 of Set 5 | san jose iturbide
# Processing Record 33 of Set 5 | champerico
# Processing Record 34 of Set 5 | mata
# Processing Record 35 of Set 5 | tuatapere
# Processing Record 36 of Set 5 | skagen
# Processing Record 37 of Set 5 | grants
# Processing Record 38 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 5 | kaitangata
# Processing Record 40 of Set 5 | bonaventure
# Processing Record 41 of Set 5 | neuquen
# Processing Record 42 of Set 5 | suntar
# Processing Record 43 of Set 5 | tocantinopolis
# City not found. Skipping...
# Processing Record 44 of Set 5 | naze
# Processing Record 45 of Set 5 | aklavik
# Processing Record 46 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 5 | tuy hoa
# Processing Record 48 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 5 | bengkulu
# Processing Record 0 of Set 6 | lahat
# Processing Record 1 of Set 6 | sturgis
# Processing Record 2 of Set 6 | slave lake
# Processing Record 3 of Set 6 | landerneau
# Processing Record 4 of Set 6 | lobito
# Processing Record 5 of Set 6 | adrar
# Processing Record 6 of Set 6 | kodiak
# Processing Record 7 of Set 6 | provideniya
# Processing Record 8 of Set 6 | margate
# Processing Record 9 of Set 6 | nioro
# Processing Record 10 of Set 6 | klaksvik
# Processing Record 11 of Set 6 | fairbanks
# Processing Record 12 of Set 6 | camacha
# Processing Record 13 of Set 6 | chokurdakh
# Processing Record 14 of Set 6 | marshall
# Processing Record 15 of Set 6 | sayyan
# Processing Record 16 of Set 6 | tazovskiy
# Processing Record 17 of Set 6 | dunedin
# Processing Record 18 of Set 6 | cabedelo
# Processing Record 19 of Set 6 | vestmannaeyjar
# Processing Record 20 of Set 6 | hay river
# Processing Record 21 of Set 6 | kahului
# Processing Record 22 of Set 6 | acajutla
# Processing Record 23 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 6 | ancud
# Processing Record 25 of Set 6 | udachnyy
# Processing Record 26 of Set 6 | phu khieo
# City not found. Skipping...
# Processing Record 27 of Set 6 | khatanga
# Processing Record 28 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | jibuti
# Processing Record 30 of Set 6 | ajdabiya
# Processing Record 31 of Set 6 | itarema
# Processing Record 32 of Set 6 | hata
# Processing Record 33 of Set 6 | shihezi
# Processing Record 34 of Set 6 | rawson
# Processing Record 35 of Set 6 | kanniyakumari
# Processing Record 36 of Set 6 | bethel
# Processing Record 37 of Set 6 | mahanoro
# Processing Record 38 of Set 6 | erenhot
# Processing Record 39 of Set 6 | gat
# Processing Record 40 of Set 6 | yancheng
# Processing Record 41 of Set 6 | saint-francois
# Processing Record 42 of Set 6 | plouzane
# Processing Record 43 of Set 6 | nanakuli
# Processing Record 44 of Set 6 | daloa
# Processing Record 45 of Set 6 | leh
# Processing Record 46 of Set 6 | saint-philippe
# Processing Record 47 of Set 6 | glendive
# Processing Record 48 of Set 6 | linxia
# Processing Record 49 of Set 6 | kushima
# Processing Record 0 of Set 7 | gouyave
# Processing Record 1 of Set 7 | goure
# Processing Record 2 of Set 7 | iqaluit
# Processing Record 3 of Set 7 | sabha
# Processing Record 4 of Set 7 | iquique
# Processing Record 5 of Set 7 | archidona
# Processing Record 6 of Set 7 | ferreira do alentejo
# Processing Record 7 of Set 7 | saint-joseph
# Processing Record 8 of Set 7 | belmonte
# Processing Record 9 of Set 7 | mulege
# Processing Record 10 of Set 7 | northam
# Processing Record 11 of Set 7 | la sarre
# Processing Record 12 of Set 7 | curup
# Processing Record 13 of Set 7 | egvekinot
# Processing Record 14 of Set 7 | damoh
# Processing Record 15 of Set 7 | dzerzhinsk
# Processing Record 16 of Set 7 | krasavino
# Processing Record 17 of Set 7 | luang prabang
# Processing Record 18 of Set 7 | tura
# Processing Record 19 of Set 7 | truth or consequences
# Processing Record 20 of Set 7 | berlevag
# Processing Record 21 of Set 7 | port macquarie
# Processing Record 22 of Set 7 | yatou
# Processing Record 23 of Set 7 | ilulissat
# Processing Record 24 of Set 7 | waconia
# Processing Record 25 of Set 7 | la asuncion
# Processing Record 26 of Set 7 | taunsa
# Processing Record 27 of Set 7 | acarau
# Processing Record 28 of Set 7 | sangar
# Processing Record 29 of Set 7 | tezu
# Processing Record 30 of Set 7 | liepaja
# Processing Record 31 of Set 7 | muroto
# Processing Record 32 of Set 7 | sosnogorsk
# Processing Record 33 of Set 7 | hervey bay
# Processing Record 34 of Set 7 | tahoua
# Processing Record 35 of Set 7 | college
# Processing Record 36 of Set 7 | salto del guaira
# Processing Record 37 of Set 7 | honningsvag
# Processing Record 38 of Set 7 | beringovskiy
# Processing Record 39 of Set 7 | praia da vitoria
# Processing Record 40 of Set 7 | lewistown
# Processing Record 41 of Set 7 | mount gambier
# Processing Record 42 of Set 7 | cap-aux-meules
# Processing Record 43 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 7 | feijo
# Processing Record 45 of Set 7 | bocas del toro
# Processing Record 46 of Set 7 | kytlym
# City not found. Skipping...
# Processing Record 47 of Set 7 | powell river
# Processing Record 48 of Set 7 | geraldton
# Processing Record 49 of Set 7 | rehoboth
# Processing Record 0 of Set 8 | srednekolymsk
# Processing Record 1 of Set 8 | nakhon thai
# Processing Record 2 of Set 8 | pangody
# Processing Record 3 of Set 8 | huarmey
# Processing Record 4 of Set 8 | vanavara
# Processing Record 5 of Set 8 | isiro
# Processing Record 6 of Set 8 | ha tinh
# Processing Record 7 of Set 8 | sladkovo
# Processing Record 8 of Set 8 | pascagoula
# Processing Record 9 of Set 8 | rocha
# Processing Record 10 of Set 8 | la rioja
# Processing Record 11 of Set 8 | gusau
# Processing Record 12 of Set 8 | okha
# Processing Record 13 of Set 8 | adeje
# Processing Record 14 of Set 8 | khanpur
# Processing Record 15 of Set 8 | arraial do cabo
# Processing Record 16 of Set 8 | sawang daen din
# Processing Record 17 of Set 8 | gold coast
# Processing Record 18 of Set 8 | san cristobal
# Processing Record 19 of Set 8 | meulaboh
# Processing Record 20 of Set 8 | cockburn town
# Processing Record 21 of Set 8 | dakar
# Processing Record 22 of Set 8 | tianpeng
# Processing Record 23 of Set 8 | krasnovishersk
# Processing Record 24 of Set 8 | loudeac
# Processing Record 25 of Set 8 | iskateley
# Processing Record 26 of Set 8 | the valley
# Processing Record 27 of Set 8 | garowe
# Processing Record 28 of Set 8 | ahipara
# Processing Record 29 of Set 8 | raga
# Processing Record 30 of Set 8 | gao
# Processing Record 31 of Set 8 | jardim
# Processing Record 32 of Set 8 | chato
# Processing Record 33 of Set 8 | uni
# Processing Record 34 of Set 8 | hambantota
# Processing Record 35 of Set 8 | kadayanallur
# Processing Record 36 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 8 | polunochnoye
# Processing Record 39 of Set 8 | inverness
# Processing Record 40 of Set 8 | quatre cocos
# Processing Record 41 of Set 8 | los llanos de aridane
# Processing Record 42 of Set 8 | mangrol
# Processing Record 43 of Set 8 | moree
# Processing Record 44 of Set 8 | boa vista
# Processing Record 45 of Set 8 | rabo de peixe
# Processing Record 46 of Set 8 | chatra
# Processing Record 47 of Set 8 | peniche
# Processing Record 48 of Set 8 | coihaique
# Processing Record 49 of Set 8 | esperance
# Processing Record 0 of Set 9 | aykhal
# Processing Record 1 of Set 9 | beyneu
# Processing Record 2 of Set 9 | yenagoa
# Processing Record 3 of Set 9 | micheweni
# Processing Record 4 of Set 9 | abbeville
# Processing Record 5 of Set 9 | mount isa
# Processing Record 6 of Set 9 | taitung
# Processing Record 7 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 9 | zheleznodorozhnyy
# Processing Record 9 of Set 9 | tandur
# Processing Record 10 of Set 9 | krasnoselkup
# Processing Record 11 of Set 9 | chippewa falls
# Processing Record 12 of Set 9 | guiyang
# Processing Record 13 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 9 | havoysund
# Processing Record 15 of Set 9 | kamaishi
# Processing Record 16 of Set 9 | te anau
# Processing Record 17 of Set 9 | sikandra rao
# Processing Record 18 of Set 9 | elliot
# Processing Record 19 of Set 9 | hanyang
# Processing Record 20 of Set 9 | buala
# Processing Record 21 of Set 9 | catuday
# Processing Record 22 of Set 9 | ternate
# Processing Record 23 of Set 9 | taoudenni
# Processing Record 24 of Set 9 | waipawa
# Processing Record 25 of Set 9 | ola
# Processing Record 26 of Set 9 | chumikan
# Processing Record 27 of Set 9 | malinyi
# Processing Record 28 of Set 9 | wynyard
# Processing Record 29 of Set 9 | ulladulla
# Processing Record 30 of Set 9 | ust-kan
# Processing Record 31 of Set 9 | tyrma
# Processing Record 32 of Set 9 | tombouctou
# Processing Record 33 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 9 | velikiy ustyug
# Processing Record 35 of Set 9 | lieksa
# Processing Record 36 of Set 9 | nishihara
# Processing Record 37 of Set 9 | zelenoborskiy
# Processing Record 38 of Set 9 | caravelas
# Processing Record 39 of Set 9 | canelones
# Processing Record 40 of Set 9 | preobrazheniye
# Processing Record 41 of Set 9 | iranshahr
# Processing Record 42 of Set 9 | srandakan
# Processing Record 43 of Set 9 | opunake
# Processing Record 44 of Set 9 | lugovoy
# Processing Record 45 of Set 9 | yumen
# Processing Record 46 of Set 9 | ishigaki
# Processing Record 47 of Set 9 | la romana
# Processing Record 48 of Set 9 | lorengau
# Processing Record 49 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 0 of Set 10 | aldan
# Processing Record 1 of Set 10 | gari
# Processing Record 2 of Set 10 | challapalle
# Processing Record 3 of Set 10 | souillac
# Processing Record 4 of Set 10 | aswan
# Processing Record 5 of Set 10 | qasigiannguit
# Processing Record 6 of Set 10 | la primavera
# Processing Record 7 of Set 10 | seymchan
# Processing Record 8 of Set 10 | harnosand
# Processing Record 9 of Set 10 | sal rei
# Processing Record 10 of Set 10 | santa fe
# Processing Record 11 of Set 10 | isangel
# Processing Record 12 of Set 10 | marrakesh
# Processing Record 13 of Set 10 | necochea
# Processing Record 14 of Set 10 | hofn
# Processing Record 15 of Set 10 | snasa
# Processing Record 16 of Set 10 | popova
# Processing Record 17 of Set 10 | miri
# Processing Record 18 of Set 10 | mildura
# Processing Record 19 of Set 10 | port-gentil
# Processing Record 20 of Set 10 | cassia
# Processing Record 21 of Set 10 | soe
# Processing Record 22 of Set 10 | muyezerskiy
# Processing Record 23 of Set 10 | cockeysville
# Processing Record 24 of Set 10 | zamora
# Processing Record 25 of Set 10 | pingliang
# Processing Record 26 of Set 10 | mogadouro
# Processing Record 27 of Set 10 | puerto escondido
# Processing Record 28 of Set 10 | kirakira
# Processing Record 29 of Set 10 | tikhvin
# Processing Record 30 of Set 10 | katobu
# Processing Record 31 of Set 10 | innisfail
# Processing Record 32 of Set 10 | logstor
# Processing Record 33 of Set 10 | esso
# Processing Record 34 of Set 10 | aksu
# Processing Record 35 of Set 10 | guhagar
# Processing Record 36 of Set 10 | alice springs
# Processing Record 37 of Set 10 | colares
# Processing Record 38 of Set 10 | zaigrayevo
# Processing Record 39 of Set 10 | tabuk
# Processing Record 40 of Set 10 | namatanai
# Processing Record 41 of Set 10 | wainwright
# Processing Record 42 of Set 10 | batemans bay
# Processing Record 43 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 10 | buin
# Processing Record 45 of Set 10 | tenosique
# Processing Record 46 of Set 10 | mollendo
# Processing Record 47 of Set 10 | eyl
# Processing Record 48 of Set 10 | arlit
# Processing Record 49 of Set 10 | xai-xai
# Processing Record 0 of Set 11 | oktyabrskiy
# Processing Record 1 of Set 11 | inongo
# Processing Record 2 of Set 11 | yeniseysk
# Processing Record 3 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 11 | marsh harbour
# Processing Record 5 of Set 11 | faanui
# Processing Record 6 of Set 11 | elizabeth city
# Processing Record 7 of Set 11 | pokotylivka
# Processing Record 8 of Set 11 | marovoay
# Processing Record 9 of Set 11 | sao filipe
# Processing Record 10 of Set 11 | malindi
# Processing Record 11 of Set 11 | general pico
# Processing Record 12 of Set 11 | sonkovo
# Processing Record 13 of Set 11 | anadyr
# Processing Record 14 of Set 11 | zhoucun
# Processing Record 15 of Set 11 | lahij
# Processing Record 16 of Set 11 | rong kwang
# Processing Record 17 of Set 11 | angoche
# Processing Record 18 of Set 11 | san jose
# Processing Record 19 of Set 11 | moa
# Processing Record 20 of Set 11 | muros
# Processing Record 21 of Set 11 | aracuai
# Processing Record 22 of Set 11 | douglas
# Processing Record 23 of Set 11 | alvorada
# Processing Record 24 of Set 11 | hinton
# Processing Record 25 of Set 11 | daru
# Processing Record 26 of Set 11 | rosetown
# Processing Record 27 of Set 11 | corinto
# Processing Record 28 of Set 11 | raubling
# Processing Record 29 of Set 11 | megalopoli
# Processing Record 30 of Set 11 | inhambane
# Processing Record 31 of Set 11 | cochrane
# Processing Record 32 of Set 11 | najran
# Processing Record 33 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 34 of Set 11 | nantucket
# Processing Record 35 of Set 11 | shelburne
# Processing Record 36 of Set 11 | novovarshavka
# Processing Record 37 of Set 11 | birsk
# Processing Record 38 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 11 | brae
# Processing Record 40 of Set 11 | yashkul
# Processing Record 41 of Set 11 | gurupa
# Processing Record 42 of Set 11 | aonla
# Processing Record 43 of Set 11 | beloha
# Processing Record 44 of Set 11 | komsomolskoye
# Processing Record 45 of Set 11 | turbat
# Processing Record 46 of Set 11 | barra
# Processing Record 47 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 11 | batagay-alyta
# Processing Record 49 of Set 11 | louga
# Processing Record 0 of Set 12 | pasni
# Processing Record 1 of Set 12 | san quintin
# Processing Record 2 of Set 12 | copiapo
# Processing Record 3 of Set 12 | half moon bay
# Processing Record 4 of Set 12 | wajima
# Processing Record 5 of Set 12 | mahibadhoo
# Processing Record 6 of Set 12 | acapulco
# Processing Record 7 of Set 12 | mushie
# Processing Record 8 of Set 12 | pacific grove
# Processing Record 9 of Set 12 | chute-aux-outardes
# Processing Record 10 of Set 12 | palmer
# Processing Record 11 of Set 12 | antalaha
# Processing Record 12 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 13 of Set 12 | zenzeli
# Processing Record 14 of Set 12 | sao joao da barra
# Processing Record 15 of Set 12 | ulsteinvik
# Processing Record 16 of Set 12 | boguchany
# Processing Record 17 of Set 12 | morro bay
# Processing Record 18 of Set 12 | hamilton
# Processing Record 19 of Set 12 | chernyshevskiy
# Processing Record 20 of Set 12 | tiarei
# Processing Record 21 of Set 12 | puerto del rosario
# Processing Record 22 of Set 12 | ostersund
# Processing Record 23 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 12 | minot
# Processing Record 25 of Set 12 | bati
# Processing Record 26 of Set 12 | moron
# Processing Record 27 of Set 12 | belaya gora
# Processing Record 28 of Set 12 | tadine
# Processing Record 29 of Set 12 | zhigansk
# Processing Record 30 of Set 12 | yamada
# Processing Record 31 of Set 12 | puerto narino
# Processing Record 32 of Set 12 | sisimiut
# Processing Record 33 of Set 12 | la ronge
# Processing Record 34 of Set 12 | davila
# Processing Record 35 of Set 12 | komsomolskiy
# Processing Record 36 of Set 12 | rio grande
# Processing Record 37 of Set 12 | yaan
# Processing Record 38 of Set 12 | cayenne
# Processing Record 39 of Set 12 | homer
# Processing Record 40 of Set 12 | hays
# Processing Record 41 of Set 12 | antofagasta
# Processing Record 42 of Set 12 | kaeo
# Processing Record 43 of Set 12 | atbasar
# Processing Record 44 of Set 12 | ukiah
# Processing Record 45 of Set 12 | atasu
# Processing Record 46 of Set 12 | port pirie
# Processing Record 47 of Set 12 | kholmogory
# Processing Record 48 of Set 12 | alakurtti
# Processing Record 49 of Set 12 | denpasar
# Processing Record 0 of Set 13 | vagur
# Processing Record 1 of Set 13 | chuncheng
# Processing Record 2 of Set 13 | san carlos de bariloche
# Processing Record 3 of Set 13 | omboue
# Processing Record 4 of Set 13 | jundubah
# City not found. Skipping...
# Processing Record 5 of Set 13 | inuvik
# Processing Record 6 of Set 13 | jensen beach
# Processing Record 7 of Set 13 | bardiyah
# Processing Record 8 of Set 13 | kavieng
# Processing Record 9 of Set 13 | blagoyevo
# Processing Record 10 of Set 13 | iquitos
# Processing Record 11 of Set 13 | skibbereen
# Processing Record 12 of Set 13 | prainha
# Processing Record 13 of Set 13 | naryan-mar
# Processing Record 14 of Set 13 | soyo
# -----------------------------
# Data Retrieval Complete: Found 573 Cities
# -----------------------------

# %%
# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp Humidity Cloudiness  Wind Speed  \
# 0      avarua -21.2078 -159.7750     86.05       74         20       17.27
# 1      mehamn  71.0357   27.8492     24.71       80         75       20.71
# 2  georgetown   5.4112  100.3354     78.73       88         20        6.91
# 3       birao  10.2849   22.7882     79.81       10         91       10.83
# 4      dallas  32.7668  -96.7836     74.16       52         20       10.36
#
#   Country        Date
# 0      CK  1677977149
# 1      NO  1677977150
# 2      MY  1677976912
# 3      CF  1677977154
# 4      US  1677976840

# %%
# Export the City_Data into a csv

city_data_df.to_csv(os.path.join("..","output_data", "cities.csv"), index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv(os.path.join("..","output_data", "cities.csv"), index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            avarua -21.2078 -159.7750     86.05        74          20
# 1            mehamn  71.0357   27.8492     24.71        80          75
# 2        georgetown   5.4112  100.3354     78.73        88          20
# 3             birao  10.2849   22.7882     79.81        10          91
# 4            dallas  32.7668  -96.7836     74.16        52          20
#
#          Wind Speed Country        Date
# City_ID
# 0             17.27      CK  1677977149
# 1             20.71      NO  1677977150
# 2              6.91      MY  1677976912
# 3             10.83      CF  1677977154
# 4             10.36      US  1677976840

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind='scatter', x='Lat', y='Max Temp',
                    title=f'Latitude vs. Temperature ({today})',
                    xlabel='Latitude', ylabel='Max Temp (F)', marker='o', edgecolors='black',
                    grid=True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig(os.path.join("..","output_data","Fig1.png"))

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind='scatter', x='Lat', y='Humidity',
                    title=f'Latitude vs. Humidity ({today})',
                    xlabel='Latitude', ylabel='Humidity (%)', marker='o', edgecolor='black',
                    grid=True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig(os.path.join("..","output_data","Fig2.png"))

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness',
                    title=f'Latitude vs. Cloudiness ({today})',
                    xlabel='Latitude', ylabel='Cloudiness (%)', marker='o', edgecolor='black',
                    grid=True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig(os.path.join("..","output_data","Fig3.png"))

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed',
                    title=f'Latitude vs. Wind Speed in MPH ({today})',
                    xlabel='Latitude', ylabel='Wind Speed (mph)', marker='o', edgecolor='black',
                    grid=True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig(os.path.join("..","output_data","Fig4.png"))

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg(x_values,y_values):
    line = np.polyfit(x_values, y_values,1)
    linear_reg_line = np.poly1d(line)
    return linear_reg_line(x_values) # This produces an array of y values between all points along the x-axis

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            mehamn  71.0357   27.8492     24.71        80          75
# 2        georgetown   5.4112  100.3354     78.73        88          20
# 3             birao  10.2849   22.7882     79.81        10          91
# 4            dallas  32.7668  -96.7836     74.16        52          20
# 5        port hardy  50.6996 -127.4199     48.20        61          75
#
#          Wind Speed Country        Date
# City_ID
# 1             20.71      NO  1677977150
# 2              6.91      MY  1677976912
# 3             10.83      CF  1677977154
# 4             10.36      US  1677976840
# 5              8.05      CA  1677976939

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df  = city_data_df[city_data_df['Lat'] < 0]


# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             avarua -21.2078 -159.7750     86.05        74          20
# 6               poum -20.2333  164.0167     80.20        76          12
# 7        new norfolk -42.7826  147.0587     76.91        50          70
# 9        broken hill -31.9500  141.4333     89.62        16           0
# 11            atuona  -9.8000 -139.0333     80.71        76           8
#
#          Wind Speed Country        Date
# City_ID
# 0             17.27      CK  1677977149
# 6              6.15      NC  1677976961
# 7              5.01      AU  1677977160
# 9              8.39      AU  1677977164
# 11            11.61      PF  1677977168

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
northern_hemi_df.plot(kind='scatter', x='Lat', y='Max Temp',
                 title='Latitude vs. Temperature', xlabel='Latitude', ylabel='Max Temp (F)', marker='x', color='steelblue')
n_lat_temp_reg = linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])

plt.plot(northern_hemi_df['Lat'], n_lat_temp_reg, color='r')
plt.show()

correlation = round(st.pearsonr(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: -0.9

# %%
# Linear regression on Southern Hemisphere
southern_hemi_df.plot(kind='scatter', x='Lat', y='Max Temp',
                 title='Latitude vs. Temperature', xlabel='Latitude', ylabel='Max Temp (F)', marker='x', color='steelblue')
s_lat_temp_reg = linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])

plt.plot(southern_hemi_df['Lat'], s_lat_temp_reg, color='r')
plt.show()

correlation = round(st.pearsonr(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.53

# %% [markdown]
# **Discussion about the linear relationship:** It appears there are fairly inverse correlations between the Northern and Southern Hemispheres in terms of Latitude to Temperature. This appears to point to temperatures rising as Latitude approaches the equator at a given point in time.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df.plot(kind='scatter', x='Lat', y='Humidity',
                 title='Latitude vs. Humidity', xlabel='Latitude', ylabel='Humidity', marker='x', color='steelblue')
n_lat_hum_reg = linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])

plt.plot(northern_hemi_df['Lat'], n_lat_hum_reg, color='r')
plt.show()

correlation = round(st.pearsonr(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.42

# %%
# Southern Hemisphere
southern_hemi_df.plot(kind='scatter', x='Lat', y='Humidity',
                 title='Latitude vs. Humidity', xlabel='Latitude', ylabel='Humidity', marker='x', color='steelblue')
s_lat_hum_reg = linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])

plt.plot(southern_hemi_df['Lat'], s_lat_hum_reg, color='r')
plt.show()

correlation = round(st.pearsonr(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.42

# %% [markdown]
# **Discussion about the linear relationship:** It appears that humidity between hemispheres are approximately the same as latitude moves away from the equator in the northern hemisphere, and moving towards the equator in the southern hemisphere. This makes sense as there is some level of humidity anywhere but is more humid closer to the equator.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df.plot(kind='scatter', x='Lat', y='Cloudiness',
                 title='Latitude vs. Cloudiness', xlabel='Latitude', ylabel='Cloudiness', marker='x', color='steelblue')
n_lat_cloud_reg = linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])

plt.plot(northern_hemi_df['Lat'], n_lat_cloud_reg, color='r')
plt.show()

correlation = round(st.pearsonr(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.39

# %%
# Southern Hemisphere
southern_hemi_df.plot(kind='scatter', x='Lat', y='Cloudiness',
                 title='Latitude vs. Cloudiness', xlabel='Latitude', ylabel='Cloudiness', marker='x', color='steelblue')
s_lat_cloud_reg = linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])

plt.plot(southern_hemi_df['Lat'], s_lat_cloud_reg, color='r')
plt.show()

correlation = round(st.pearsonr(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.36

# %% [markdown]
# **Discussion about the linear relationship:** There appears to be a fairly weak positive correlation between the two hemispheres in terms of cloudiness to latitude. This makes some sense because any point in the world could be covered by clouds or storms at any point in time. This also shows there tends to be more clouds near the equator which makes sense because of tropical storms in a given season.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df.plot(kind='scatter', x='Lat', y='Wind Speed',
                 title='Latitude vs. Wind Speed (mph)', xlabel='Latitude', ylabel='Wind Speed (mph)', marker='x', color='steelblue')
n_lat_wind_reg = linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])

plt.plot(northern_hemi_df['Lat'], n_lat_wind_reg, color='r')
plt.show()

correlation = round(st.pearsonr(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.11

# %%
# Southern Hemisphere
southern_hemi_df.plot(kind='scatter', x='Lat', y='Wind Speed',
                 title='Latitude vs. Wind Speed (mph)', xlabel='Latitude', ylabel='Wind Speed (mph)', marker='x', color='steelblue')
s_lat_wind_reg = linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])

plt.plot(southern_hemi_df['Lat'], s_lat_wind_reg, color='r')
plt.show()

correlation = round(st.pearsonr(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: -0.16

# %% [markdown]
# **Discussion about the linear relationship:** There is very weak correlation here. This makes sense as wind speeds do not tend to be specific to regions. However, the correlation could speak to being closer to the equator as wind speeds may be more consistent and related to tropical storms in a given season.
