# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Identify Today's Date
today = pd.to_datetime('today').normalize().strftime("%m-%d-%Y")
print(f"Today is: {today}")

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Today is: 03-04-2023
# Number of cities in the list: 606

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
api_key = weather_api_key
units = "metric"

# Define Empty Data Frame to store city data
city_data_df = pd.DataFrame(columns=['City', 'Lat', 'Lng', 'Max Temp','Humidity', 'Cloudiness',
                                     'Wind Speed', 'Country', 'Date'])

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    time.sleep(1)    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_data = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_data['coord']['lat']
        city_lng = city_data['coord']['lon']
        city_max_temp = city_data['main']['temp_max']
        city_humidity = city_data['main']['humidity']
        city_clouds = city_data['clouds']['all']
        city_wind = city_data['wind']['speed']
        city_country = city_data['sys']['country']
        city_date = city_data['dt']

        # Append the City Data into city_data_df
        temp_df = pd.DataFrame({  "City": city, 
                                  "Lat": city_lat, 
                                  "Lng": city_lng, 
                                  "Max Temp": city_max_temp,
                                  "Humidity": city_humidity,
                                  "Cloudiness": city_clouds,
                                  "Wind Speed": city_wind,
                                  "Country": city_country,
                                  "Date": city_date},
                                                     index=[0])

        city_data_df = pd.concat([city_data_df, temp_df], axis=0,ignore_index=True)
        
    except:
        print("City not found. Skipping...")
        pass
        
        
# Indicate that Data Loading is complete 
print("-----------------------------")
print(f"Data Retrieval Complete: Found {len(city_data_df)} of {len(cities)} Cities")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | benjamin constant
# Processing Record 2 of Set 1 | lompoc
# Processing Record 3 of Set 1 | kisanga
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | klaksvik
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | wajid
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | kaduqli
# Processing Record 19 of Set 1 | sibolga
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | vardo
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | ouranopolis
# City not found. Skipping...
# Processing Record 26 of Set 1 | ada
# Processing Record 27 of Set 1 | tabuk
# Processing Record 28 of Set 1 | vallenar
# Processing Record 29 of Set 1 | ejura
# Processing Record 30 of Set 1 | coihaique
# Processing Record 31 of Set 1 | manakara
# Processing Record 32 of Set 1 | alofi
# Processing Record 33 of Set 1 | pacific grove
# Processing Record 34 of Set 1 | raudeberg
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | medea
# Processing Record 37 of Set 1 | pilar
# Processing Record 38 of Set 1 | dekar
# Processing Record 39 of Set 1 | kurilsk
# Processing Record 40 of Set 1 | santa cruz
# Processing Record 41 of Set 1 | moree
# Processing Record 42 of Set 1 | krasnoselkup
# Processing Record 43 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | kruisfontein
# Processing Record 46 of Set 1 | taksimo
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | cutcut
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | kuala lumpur
# Processing Record 0 of Set 2 | hermanus
# Processing Record 1 of Set 2 | ustye
# Processing Record 2 of Set 2 | katsuura
# Processing Record 3 of Set 2 | provideniya
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | kununurra
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | plattsburgh
# Processing Record 12 of Set 2 | axim
# Processing Record 13 of Set 2 | inirida
# Processing Record 14 of Set 2 | sioux lookout
# Processing Record 15 of Set 2 | clyde river
# Processing Record 16 of Set 2 | gijon
# Processing Record 17 of Set 2 | esik
# Processing Record 18 of Set 2 | caravelas
# Processing Record 19 of Set 2 | ostrovnoy
# Processing Record 20 of Set 2 | uddevalla
# Processing Record 21 of Set 2 | luderitz
# Processing Record 22 of Set 2 | khandyga
# Processing Record 23 of Set 2 | cascais
# Processing Record 24 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 2 | oranjestad
# Processing Record 26 of Set 2 | garowe
# Processing Record 27 of Set 2 | henties bay
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | neiafu
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 2 | cap malheureux
# Processing Record 35 of Set 2 | ardistan
# City not found. Skipping...
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | kaitangata
# Processing Record 42 of Set 2 | kabirwala
# Processing Record 43 of Set 2 | madaoua
# Processing Record 44 of Set 2 | zhetybay
# City not found. Skipping...
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | grindavik
# Processing Record 47 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 48 of Set 2 | lubbock
# Processing Record 49 of Set 2 | baghdad
# Processing Record 0 of Set 3 | beringovskiy
# Processing Record 1 of Set 3 | lavrentiya
# Processing Record 2 of Set 3 | cockburn town
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | norman wells
# Processing Record 5 of Set 3 | christchurch
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | ahipara
# Processing Record 9 of Set 3 | los llanos de aridane
# Processing Record 10 of Set 3 | pochutla
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | camargo
# Processing Record 14 of Set 3 | ancud
# Processing Record 15 of Set 3 | tokuyama
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | belyy yar
# Processing Record 18 of Set 3 | evensk
# Processing Record 19 of Set 3 | albion
# Processing Record 20 of Set 3 | peniche
# Processing Record 21 of Set 3 | ulagan
# Processing Record 22 of Set 3 | kropotkin
# Processing Record 23 of Set 3 | hobart
# Processing Record 24 of Set 3 | san marcos
# Processing Record 25 of Set 3 | dwarka
# Processing Record 26 of Set 3 | cartagena
# Processing Record 27 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 28 of Set 3 | necocli
# Processing Record 29 of Set 3 | cururupu
# Processing Record 30 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 3 | carnarvon
# Processing Record 32 of Set 3 | bambous virieux
# Processing Record 33 of Set 3 | ihosy
# Processing Record 34 of Set 3 | prince rupert
# Processing Record 35 of Set 3 | banjarmasin
# Processing Record 36 of Set 3 | kapaa
# Processing Record 37 of Set 3 | margate
# Processing Record 38 of Set 3 | oranjemund
# Processing Record 39 of Set 3 | vestmannaeyjar
# Processing Record 40 of Set 3 | tateyama
# Processing Record 41 of Set 3 | karratha
# Processing Record 42 of Set 3 | svetlyy
# Processing Record 43 of Set 3 | borisoglebskiy
# Processing Record 44 of Set 3 | port blair
# Processing Record 45 of Set 3 | hualmay
# Processing Record 46 of Set 3 | kungurtug
# Processing Record 47 of Set 3 | fortuna
# Processing Record 48 of Set 3 | morant bay
# Processing Record 49 of Set 3 | mimongo
# Processing Record 0 of Set 4 | nikolskoye
# Processing Record 1 of Set 4 | myszkow
# Processing Record 2 of Set 4 | itarema
# Processing Record 3 of Set 4 | parrita
# Processing Record 4 of Set 4 | pevek
# Processing Record 5 of Set 4 | asau
# Processing Record 6 of Set 4 | idrinskoye
# Processing Record 7 of Set 4 | avarua
# Processing Record 8 of Set 4 | east london
# Processing Record 9 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4 | macamic
# Processing Record 11 of Set 4 | shahr-e babak
# Processing Record 12 of Set 4 | tiksi
# Processing Record 13 of Set 4 | souillac
# Processing Record 14 of Set 4 | iqaluit
# Processing Record 15 of Set 4 | hakkari
# Processing Record 16 of Set 4 | cherskiy
# Processing Record 17 of Set 4 | angoche
# Processing Record 18 of Set 4 | saint pete beach
# Processing Record 19 of Set 4 | sao gabriel da cachoeira
# Processing Record 20 of Set 4 | college
# Processing Record 21 of Set 4 | rio branco do sul
# Processing Record 22 of Set 4 | susehri
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | santa isabel do rio negro
# Processing Record 25 of Set 4 | dikson
# Processing Record 26 of Set 4 | butaritari
# Processing Record 27 of Set 4 | lasa
# Processing Record 28 of Set 4 | torbay
# Processing Record 29 of Set 4 | suzu
# City not found. Skipping...
# Processing Record 30 of Set 4 | veraval
# Processing Record 31 of Set 4 | ardino
# Processing Record 32 of Set 4 | orlik
# Processing Record 33 of Set 4 | coxim
# Processing Record 34 of Set 4 | tarata
# Processing Record 35 of Set 4 | constitucion
# Processing Record 36 of Set 4 | gravdal
# Processing Record 37 of Set 4 | baranain
# Processing Record 38 of Set 4 | sorland
# Processing Record 39 of Set 4 | guymon
# Processing Record 40 of Set 4 | khatanga
# Processing Record 41 of Set 4 | georgetown
# Processing Record 42 of Set 4 | ligayan
# Processing Record 43 of Set 4 | kysyl-syr
# Processing Record 44 of Set 4 | mangaluru
# Processing Record 45 of Set 4 | chumikan
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | aswan
# Processing Record 48 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 4 | amazar
# Processing Record 0 of Set 5 | coatesville
# Processing Record 1 of Set 5 | santa rosa
# Processing Record 2 of Set 5 | west wendover
# Processing Record 3 of Set 5 | ponta delgada
# Processing Record 4 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | burnie
# Processing Record 7 of Set 5 | rzhyshchiv
# Processing Record 8 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 5 | bengkulu
# Processing Record 10 of Set 5 | comodoro rivadavia
# Processing Record 11 of Set 5 | yulara
# Processing Record 12 of Set 5 | gazojak
# Processing Record 13 of Set 5 | baldone
# Processing Record 14 of Set 5 | kuching
# Processing Record 15 of Set 5 | nanortalik
# Processing Record 16 of Set 5 | eureka
# Processing Record 17 of Set 5 | kahului
# Processing Record 18 of Set 5 | cam ranh
# Processing Record 19 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 5 | oksfjord
# Processing Record 21 of Set 5 | khash
# Processing Record 22 of Set 5 | walvis bay
# Processing Record 23 of Set 5 | piranhas
# Processing Record 24 of Set 5 | touros
# Processing Record 25 of Set 5 | saint-augustin
# Processing Record 26 of Set 5 | tungor
# Processing Record 27 of Set 5 | bien hoa
# Processing Record 28 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 5 | nisia floresta
# Processing Record 30 of Set 5 | anadyr
# Processing Record 31 of Set 5 | dicabisagan
# Processing Record 32 of Set 5 | iranshahr
# Processing Record 33 of Set 5 | roma
# Processing Record 34 of Set 5 | sao sebastiao
# Processing Record 35 of Set 5 | shirokiy
# Processing Record 36 of Set 5 | barrow
# Processing Record 37 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 5 | mount gambier
# Processing Record 39 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 40 of Set 5 | altay
# Processing Record 41 of Set 5 | mahebourg
# Processing Record 42 of Set 5 | nianzishan
# Processing Record 43 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 5 | churapcha
# Processing Record 45 of Set 5 | jamestown
# Processing Record 46 of Set 5 | beloha
# Processing Record 47 of Set 5 | buala
# Processing Record 48 of Set 5 | belaya gora
# Processing Record 49 of Set 5 | wamba
# Processing Record 0 of Set 6 | alice springs
# Processing Record 1 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 6 | ahuimanu
# Processing Record 3 of Set 6 | dubbo
# Processing Record 4 of Set 6 | lishui
# Processing Record 5 of Set 6 | akureyri
# Processing Record 6 of Set 6 | briancon
# Processing Record 7 of Set 6 | tadine
# Processing Record 8 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 6 | dingle
# Processing Record 10 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 6 | codrington
# Processing Record 12 of Set 6 | liwale
# Processing Record 13 of Set 6 | isangel
# Processing Record 14 of Set 6 | husavik
# Processing Record 15 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 6 | fort-shevchenko
# Processing Record 17 of Set 6 | bubaque
# Processing Record 18 of Set 6 | tigil
# Processing Record 19 of Set 6 | severo-kurilsk
# Processing Record 20 of Set 6 | haines junction
# Processing Record 21 of Set 6 | victoria
# Processing Record 22 of Set 6 | kloulklubed
# Processing Record 23 of Set 6 | bongaree
# Processing Record 24 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 6 | jalu
# Processing Record 26 of Set 6 | kutum
# Processing Record 27 of Set 6 | jumla
# Processing Record 28 of Set 6 | feijo
# Processing Record 29 of Set 6 | tabory
# Processing Record 30 of Set 6 | manadhoo
# Processing Record 31 of Set 6 | mitsamiouli
# Processing Record 32 of Set 6 | antofagasta
# Processing Record 33 of Set 6 | mansa
# Processing Record 34 of Set 6 | kavaratti
# Processing Record 35 of Set 6 | biltine
# Processing Record 36 of Set 6 | magnolia
# Processing Record 37 of Set 6 | san cristobal
# Processing Record 38 of Set 6 | progreso
# Processing Record 39 of Set 6 | viedma
# Processing Record 40 of Set 6 | san patricio
# Processing Record 41 of Set 6 | mangalia
# Processing Record 42 of Set 6 | mana
# Processing Record 43 of Set 6 | khao yoi
# Processing Record 44 of Set 6 | sokolo
# Processing Record 45 of Set 6 | katha
# City not found. Skipping...
# Processing Record 46 of Set 6 | belmonte
# Processing Record 47 of Set 6 | bowen
# Processing Record 48 of Set 6 | faanui
# Processing Record 49 of Set 6 | gaya
# Processing Record 0 of Set 7 | ca mau
# Processing Record 1 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 7 | narsaq
# Processing Record 3 of Set 7 | paso de los toros
# Processing Record 4 of Set 7 | katherine
# Processing Record 5 of Set 7 | rypefjord
# Processing Record 6 of Set 7 | port elizabeth
# Processing Record 7 of Set 7 | uyemskiy
# Processing Record 8 of Set 7 | manuk mangkaw
# Processing Record 9 of Set 7 | lakes entrance
# Processing Record 10 of Set 7 | bandarbeyla
# Processing Record 11 of Set 7 | khorixas
# Processing Record 12 of Set 7 | kavieng
# Processing Record 13 of Set 7 | shelburne
# Processing Record 14 of Set 7 | almeria
# Processing Record 15 of Set 7 | saint george
# Processing Record 16 of Set 7 | bud
# Processing Record 17 of Set 7 | hornepayne
# Processing Record 18 of Set 7 | ilulissat
# Processing Record 19 of Set 7 | salcedo
# Processing Record 20 of Set 7 | nosy varika
# Processing Record 21 of Set 7 | ambatofinandrahana
# Processing Record 22 of Set 7 | north bend
# Processing Record 23 of Set 7 | bima
# Processing Record 24 of Set 7 | svetlaya
# Processing Record 25 of Set 7 | salvador
# Processing Record 26 of Set 7 | nouadhibou
# Processing Record 27 of Set 7 | bull savanna
# Processing Record 28 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 29 of Set 7 | marau
# Processing Record 30 of Set 7 | te anau
# Processing Record 31 of Set 7 | port hedland
# Processing Record 32 of Set 7 | acapulco
# Processing Record 33 of Set 7 | chapleau
# Processing Record 34 of Set 7 | atherton
# Processing Record 35 of Set 7 | tiznit
# Processing Record 36 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 7 | matane
# Processing Record 38 of Set 7 | baracoa
# Processing Record 39 of Set 7 | kisangani
# Processing Record 40 of Set 7 | hazorasp
# Processing Record 41 of Set 7 | adrar
# Processing Record 42 of Set 7 | la ronge
# Processing Record 43 of Set 7 | kabo
# Processing Record 44 of Set 7 | salalah
# Processing Record 45 of Set 7 | vysokogornyy
# Processing Record 46 of Set 7 | umm lajj
# Processing Record 47 of Set 7 | meulaboh
# Processing Record 48 of Set 7 | rio grande
# Processing Record 49 of Set 7 | kaseda
# Processing Record 0 of Set 8 | north platte
# Processing Record 1 of Set 8 | basco
# Processing Record 2 of Set 8 | satipo
# Processing Record 3 of Set 8 | bonavista
# Processing Record 4 of Set 8 | yar-sale
# Processing Record 5 of Set 8 | creston
# Processing Record 6 of Set 8 | tres arroyos
# Processing Record 7 of Set 8 | coquimbo
# Processing Record 8 of Set 8 | ucluelet
# Processing Record 9 of Set 8 | champerico
# Processing Record 10 of Set 8 | yamada
# Processing Record 11 of Set 8 | omsukchan
# Processing Record 12 of Set 8 | acarau
# Processing Record 13 of Set 8 | praia
# Processing Record 14 of Set 8 | grand gaube
# Processing Record 15 of Set 8 | talnakh
# Processing Record 16 of Set 8 | ornskoldsvik
# Processing Record 17 of Set 8 | deputatskiy
# Processing Record 18 of Set 8 | zwedru
# Processing Record 19 of Set 8 | talaya
# Processing Record 20 of Set 8 | rivers
# Processing Record 21 of Set 8 | san roque
# Processing Record 22 of Set 8 | salinas
# Processing Record 23 of Set 8 | kamenka
# Processing Record 24 of Set 8 | monrovia
# Processing Record 25 of Set 8 | nata
# Processing Record 26 of Set 8 | biak
# Processing Record 27 of Set 8 | nyakabindi
# Processing Record 28 of Set 8 | nokaneng
# Processing Record 29 of Set 8 | san borja
# Processing Record 30 of Set 8 | esperance
# Processing Record 31 of Set 8 | lixourion
# Processing Record 32 of Set 8 | omis
# Processing Record 33 of Set 8 | ust-nera
# Processing Record 34 of Set 8 | paraiso
# Processing Record 35 of Set 8 | rawson
# Processing Record 36 of Set 8 | malanje
# Processing Record 37 of Set 8 | clarence town
# Processing Record 38 of Set 8 | flinders
# Processing Record 39 of Set 8 | fare
# Processing Record 40 of Set 8 | grao mogol
# Processing Record 41 of Set 8 | hope
# Processing Record 42 of Set 8 | ispica
# Processing Record 43 of Set 8 | fomboni
# Processing Record 44 of Set 8 | kulunda
# Processing Record 45 of Set 8 | santa fe
# Processing Record 46 of Set 8 | plainview
# Processing Record 47 of Set 8 | noumea
# Processing Record 48 of Set 8 | tucuma
# Processing Record 49 of Set 8 | viseu
# Processing Record 0 of Set 9 | auki
# Processing Record 1 of Set 9 | caluquembe
# Processing Record 2 of Set 9 | geraldton
# Processing Record 3 of Set 9 | bilibino
# Processing Record 4 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 5 of Set 9 | shingu
# Processing Record 6 of Set 9 | moose factory
# Processing Record 7 of Set 9 | doka
# Processing Record 8 of Set 9 | taseyevo
# Processing Record 9 of Set 9 | skjervoy
# Processing Record 10 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 9 | baoqing
# Processing Record 12 of Set 9 | vitim
# Processing Record 13 of Set 9 | paamiut
# Processing Record 14 of Set 9 | rocha
# Processing Record 15 of Set 9 | abha
# Processing Record 16 of Set 9 | springbok
# Processing Record 17 of Set 9 | guantanamo
# Processing Record 18 of Set 9 | sitka
# Processing Record 19 of Set 9 | burica
# City not found. Skipping...
# Processing Record 20 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 21 of Set 9 | boueni
# Processing Record 22 of Set 9 | aksu
# Processing Record 23 of Set 9 | richards bay
# Processing Record 24 of Set 9 | ayame
# Processing Record 25 of Set 9 | agropoli
# Processing Record 26 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 9 | corner brook
# Processing Record 28 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 9 | ascoli piceno
# Processing Record 30 of Set 9 | sivaki
# Processing Record 31 of Set 9 | srednekolymsk
# Processing Record 32 of Set 9 | pangnirtung
# Processing Record 33 of Set 9 | nautla
# Processing Record 34 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 35 of Set 9 | karaton
# Processing Record 36 of Set 9 | tarko-sale
# Processing Record 37 of Set 9 | coahuayana
# Processing Record 38 of Set 9 | turayf
# Processing Record 39 of Set 9 | russellville
# Processing Record 40 of Set 9 | lukulu
# Processing Record 41 of Set 9 | marion
# Processing Record 42 of Set 9 | venice
# Processing Record 43 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 44 of Set 9 | pembroke
# Processing Record 45 of Set 9 | norsup
# Processing Record 46 of Set 9 | qasigiannguit
# Processing Record 47 of Set 9 | nimbahera
# Processing Record 48 of Set 9 | sauda
# Processing Record 49 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 0 of Set 10 | yuanping
# Processing Record 1 of Set 10 | bedford
# Processing Record 2 of Set 10 | back mountain
# Processing Record 3 of Set 10 | nhulunbuy
# Processing Record 4 of Set 10 | naze
# Processing Record 5 of Set 10 | kondinskoye
# Processing Record 6 of Set 10 | ballitoville
# Processing Record 7 of Set 10 | lazaro cardenas
# Processing Record 8 of Set 10 | cabedelo
# Processing Record 9 of Set 10 | fukue
# Processing Record 10 of Set 10 | mascote
# Processing Record 11 of Set 10 | sayyan
# Processing Record 12 of Set 10 | hofn
# Processing Record 13 of Set 10 | gorontalo
# Processing Record 14 of Set 10 | sabancuy
# Processing Record 15 of Set 10 | lerwick
# Processing Record 16 of Set 10 | young
# Processing Record 17 of Set 10 | harper
# Processing Record 18 of Set 10 | lorengau
# Processing Record 19 of Set 10 | cidreira
# Processing Record 20 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 21 of Set 10 | oussouye
# Processing Record 22 of Set 10 | thinadhoo
# Processing Record 23 of Set 10 | portland
# Processing Record 24 of Set 10 | cedar city
# Processing Record 25 of Set 10 | omboue
# Processing Record 26 of Set 10 | guerrero negro
# Processing Record 27 of Set 10 | markala
# Processing Record 28 of Set 10 | ye
# City not found. Skipping...
# Processing Record 29 of Set 10 | hami
# Processing Record 30 of Set 10 | vostok
# Processing Record 31 of Set 10 | bangassou
# Processing Record 32 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 33 of Set 10 | mao
# Processing Record 34 of Set 10 | pacifica
# Processing Record 35 of Set 10 | aklavik
# Processing Record 36 of Set 10 | komsomolskiy
# Processing Record 37 of Set 10 | borinskoye
# Processing Record 38 of Set 10 | bafia
# Processing Record 39 of Set 10 | lusambo
# Processing Record 40 of Set 10 | bundaberg
# Processing Record 41 of Set 10 | ciudad bolivar
# Processing Record 42 of Set 10 | griffith
# Processing Record 43 of Set 10 | labuan
# Processing Record 44 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 10 | ormara
# Processing Record 46 of Set 10 | stornoway
# Processing Record 47 of Set 10 | gat
# Processing Record 48 of Set 10 | mwanza
# Processing Record 49 of Set 10 | kilindoni
# Processing Record 0 of Set 11 | lulea
# Processing Record 1 of Set 11 | hambantota
# Processing Record 2 of Set 11 | abrau-dyurso
# Processing Record 3 of Set 11 | nassjo
# Processing Record 4 of Set 11 | dera bugti
# Processing Record 5 of Set 11 | shubarkuduk
# Processing Record 6 of Set 11 | limbang
# Processing Record 7 of Set 11 | rzhaksa
# Processing Record 8 of Set 11 | palmer
# Processing Record 9 of Set 11 | azrow
# City not found. Skipping...
# Processing Record 10 of Set 11 | aripuana
# Processing Record 11 of Set 11 | kalemie
# Processing Record 12 of Set 11 | odienne
# Processing Record 13 of Set 11 | powell river
# Processing Record 14 of Set 11 | jackson
# Processing Record 15 of Set 11 | taman
# Processing Record 16 of Set 11 | nizhniy kuranakh
# Processing Record 17 of Set 11 | nyurba
# Processing Record 18 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 11 | kroya
# Processing Record 20 of Set 11 | okhtyrka
# Processing Record 21 of Set 11 | makinsk
# Processing Record 22 of Set 11 | fort nelson
# Processing Record 23 of Set 11 | thunder bay
# Processing Record 24 of Set 11 | boa vista
# Processing Record 25 of Set 11 | lata
# Processing Record 26 of Set 11 | barra patuca
# Processing Record 27 of Set 11 | henstedt-ulzburg
# Processing Record 28 of Set 11 | poum
# Processing Record 29 of Set 11 | urumqi
# Processing Record 30 of Set 11 | plettenberg bay
# Processing Record 31 of Set 11 | bathsheba
# Processing Record 32 of Set 11 | vanimo
# Processing Record 33 of Set 11 | san carlos de bariloche
# Processing Record 34 of Set 11 | ketchikan
# Processing Record 35 of Set 11 | turinskaya sloboda
# Processing Record 36 of Set 11 | cayenne
# Processing Record 37 of Set 11 | nathdwara
# Processing Record 38 of Set 11 | ballina
# Processing Record 39 of Set 11 | teloloapan
# Processing Record 40 of Set 11 | rock sound
# Processing Record 41 of Set 11 | tole
# Processing Record 42 of Set 11 | adwa
# Processing Record 43 of Set 11 | arlit
# Processing Record 44 of Set 11 | olafsvik
# Processing Record 45 of Set 11 | la seyne-sur-mer
# Processing Record 46 of Set 11 | bani walid
# Processing Record 47 of Set 11 | salta
# Processing Record 48 of Set 11 | sinop
# Processing Record 49 of Set 11 | pozo colorado
# Processing Record 0 of Set 12 | aykhal
# Processing Record 1 of Set 12 | sokur
# Processing Record 2 of Set 12 | leningradskiy
# Processing Record 3 of Set 12 | goderich
# Processing Record 4 of Set 12 | ulladulla
# Processing Record 5 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 12 | moville
# Processing Record 7 of Set 12 | dolores
# Processing Record 8 of Set 12 | betanzos
# Processing Record 9 of Set 12 | aquiraz
# Processing Record 10 of Set 12 | quatre cocos
# Processing Record 11 of Set 12 | monte cristi
# City not found. Skipping...
# Processing Record 12 of Set 12 | alta floresta
# Processing Record 13 of Set 12 | padang
# Processing Record 14 of Set 12 | cape coast
# Processing Record 15 of Set 12 | mahibadhoo
# Processing Record 16 of Set 12 | porto novo
# Processing Record 17 of Set 12 | hamilton
# Processing Record 18 of Set 12 | ixtapa
# Processing Record 19 of Set 12 | nantucket
# Processing Record 20 of Set 12 | seydi
# Processing Record 21 of Set 12 | seoul
# Processing Record 22 of Set 12 | kesennuma
# City not found. Skipping...
# Processing Record 23 of Set 12 | dunedin
# Processing Record 24 of Set 12 | samarai
# Processing Record 25 of Set 12 | miles city
# Processing Record 26 of Set 12 | lokken verk
# City not found. Skipping...
# Processing Record 27 of Set 12 | cordoba
# Processing Record 28 of Set 12 | safford
# Processing Record 29 of Set 12 | kupang
# Processing Record 30 of Set 12 | havre-saint-pierre
# Processing Record 31 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 12 | mitchell
# Processing Record 33 of Set 12 | am timan
# Processing Record 34 of Set 12 | turbat
# Processing Record 35 of Set 12 | mango
# Processing Record 36 of Set 12 | kanevskaya
# Processing Record 37 of Set 12 | zhigansk
# Processing Record 38 of Set 12 | ron
# Processing Record 39 of Set 12 | sao joao da barra
# Processing Record 40 of Set 12 | sobolevo
# Processing Record 41 of Set 12 | saint-joseph
# Processing Record 42 of Set 12 | bilma
# Processing Record 43 of Set 12 | saint anthony
# Processing Record 44 of Set 12 | sovetskiy
# Processing Record 45 of Set 12 | ipixuna
# Processing Record 46 of Set 12 | vila velha
# Processing Record 47 of Set 12 | mayo
# Processing Record 48 of Set 12 | bobonong
# City not found. Skipping...
# Processing Record 49 of Set 12 | calvia
# Processing Record 0 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 1 of Set 13 | kerema
# Processing Record 2 of Set 13 | ust-ishim
# Processing Record 3 of Set 13 | saint-pierre
# Processing Record 4 of Set 13 | samarkand
# Processing Record 5 of Set 13 | punta gorda
# -----------------------------
# Data Retrieval Complete: Found 551 of 606 Cities
# -----------------------------

# %%
# Show Record Count
city_data_df.count()
# Out:
# City          551
# Lat           551
# Lng           551
# Max Temp      551
# Humidity      551
# Cloudiness    551
# Wind Speed    551
# Country       551
# Date          551
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp Humidity Cloudiness  \
# 0  benjamin constant  -4.3831  -70.0311     24.07       99        100
# 1             lompoc  34.6391 -120.4579     10.89       82        100
# 2            kisanga  -7.4362   37.7034     21.54       91         90
# 3             albany  42.6001  -73.9662      0.91       91         99
# 4             kodiak  57.7900 -152.4072      0.73       55          0
#
#    Wind Speed Country        Date
# 0        1.03      BR  1677988124
# 1        2.06      US  1677988125
# 2        0.92      TZ  1677988127
# 3        4.03      US  1677987946
# 4        3.09      US  1677988131

# %%
# Export the City_Data into a csv

city_data_df.to_csv(os.path.join("..","output_data", "cities.csv"), index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv(os.path.join("..","output_data", "cities.csv"), index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        benjamin constant  -4.3831  -70.0311     24.07        99         100
# 1                   lompoc  34.6391 -120.4579     10.89        82         100
# 2                  kisanga  -7.4362   37.7034     21.54        91          90
# 3                   albany  42.6001  -73.9662      0.91        91          99
# 4                   kodiak  57.7900 -152.4072      0.73        55           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.03      BR  1677988124
# 1              2.06      US  1677988125
# 2              0.92      TZ  1677988127
# 3              4.03      US  1677987946
# 4              3.09      US  1677988131

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind='scatter', x='Lat', y='Max Temp',
                    title=f'Latitude vs. Temperature ({today})',
                    xlabel='Latitude', ylabel='Max Temp (C)', marker='o', edgecolors='black',
                    grid=True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig(os.path.join("..","output_data","Fig1.png"))

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind='scatter', x='Lat', y='Humidity',
                    title=f'Latitude vs. Humidity ({today})',
                    xlabel='Latitude', ylabel='Humidity (%)', marker='o', edgecolor='black',
                    grid=True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig(os.path.join("..","output_data","Fig2.png"))

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness',
                    title=f'Latitude vs. Cloudiness ({today})',
                    xlabel='Latitude', ylabel='Cloudiness (%)', marker='o', edgecolor='black',
                    grid=True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig(os.path.join("..","output_data","Fig3.png"))

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed',
                    title=f'Latitude vs. Wind Speed ({today})',
                    xlabel='Latitude', ylabel='Wind Speed (m/s)', marker='o', edgecolor='black',
                    grid=True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig(os.path.join("..","output_data","Fig4.png"))

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg(x_values,y_values):
    line = np.polyfit(x_values, y_values,1)
    linear_reg_line = np.poly1d(line)
    return linear_reg_line(x_values) # This produces an array of y values between all points along the x-axis

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          lompoc  34.6391 -120.4579     10.89        82         100
# 3          albany  42.6001  -73.9662      0.91        91          99
# 4          kodiak  57.7900 -152.4072      0.73        55           0
# 6        klaksvik  62.2266   -6.5890      1.51        72         100
# 9         qaanaaq  77.4840  -69.3632    -10.41        48          72
#
#          Wind Speed Country        Date
# City_ID
# 1              2.06      US  1677988125
# 3              4.03      US  1677987946
# 4              3.09      US  1677988131
# 6              1.80      FO  1677988133
# 9              4.47      GL  1677988138

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df  = city_data_df[city_data_df['Lat'] < 0]


# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        benjamin constant  -4.3831  -70.0311     24.07        99         100
# 2                  kisanga  -7.4362   37.7034     21.54        91          90
# 5                  mataura -46.1927  168.8643     15.77        47          48
# 7                     lebu -37.6167  -73.6500     13.53        74           0
# 8           saint-philippe -21.3585   55.7679     24.77        85         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.03      BR  1677988124
# 2              0.92      TZ  1677988127
# 5              2.24      NZ  1677988132
# 7              6.73      CL  1677987607
# 8              3.06      RE  1677988137

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
northern_hemi_df.plot(kind='scatter', x='Lat', y='Max Temp',
                 title='Latitude vs. Temperature', xlabel='Latitude', ylabel='Max Temp (C)', marker='x', color='steelblue')
n_lat_temp_reg = linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])

plt.plot(northern_hemi_df['Lat'], n_lat_temp_reg, color='r')
plt.show()

correlation = round(st.pearsonr(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: -0.9

# %%
# Linear regression on Southern Hemisphere
southern_hemi_df.plot(kind='scatter', x='Lat', y='Max Temp',
                 title='Latitude vs. Temperature', xlabel='Latitude', ylabel='Max Temp (C)', marker='x', color='steelblue')
s_lat_temp_reg = linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])

plt.plot(southern_hemi_df['Lat'], s_lat_temp_reg, color='r')
plt.show()

correlation = round(st.pearsonr(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.44

# %% [markdown]
# **Discussion about the linear relationship:** It appears there are fairly inverse correlations between the Northern and Southern Hemispheres in terms of Latitude to Temperature. This appears to point to temperatures rising as Latitude approaches the equator at a given point in time.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df.plot(kind='scatter', x='Lat', y='Humidity',
                 title='Latitude vs. Humidity', xlabel='Latitude', ylabel='Humidity', marker='x', color='steelblue')
n_lat_hum_reg = linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])

plt.plot(northern_hemi_df['Lat'], n_lat_hum_reg, color='r')
plt.show()

correlation = round(st.pearsonr(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.33

# %%
# Southern Hemisphere
southern_hemi_df.plot(kind='scatter', x='Lat', y='Humidity',
                 title='Latitude vs. Humidity', xlabel='Latitude', ylabel='Humidity', marker='x', color='steelblue')
s_lat_hum_reg = linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])

plt.plot(southern_hemi_df['Lat'], s_lat_hum_reg, color='r')
plt.show()

correlation = round(st.pearsonr(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.34

# %% [markdown]
# **Discussion about the linear relationship:** It appears that humidity between hemispheres are approximately the same as latitude moves away from the equator in the northern hemisphere, and moving towards the equator in the southern hemisphere. This makes sense as there is some level of humidity anywhere but is more humid closer to the equator.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df.plot(kind='scatter', x='Lat', y='Cloudiness',
                 title='Latitude vs. Cloudiness', xlabel='Latitude', ylabel='Cloudiness', marker='x', color='steelblue')
n_lat_cloud_reg = linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])

plt.plot(northern_hemi_df['Lat'], n_lat_cloud_reg, color='r')
plt.show()

correlation = round(st.pearsonr(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.3

# %%
# Southern Hemisphere
southern_hemi_df.plot(kind='scatter', x='Lat', y='Cloudiness',
                 title='Latitude vs. Cloudiness', xlabel='Latitude', ylabel='Cloudiness', marker='x', color='steelblue')
s_lat_cloud_reg = linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])

plt.plot(southern_hemi_df['Lat'], s_lat_cloud_reg, color='r')
plt.show()

correlation = round(st.pearsonr(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.31

# %% [markdown]
# **Discussion about the linear relationship:** There appears to be a fairly weak positive correlation between the two hemispheres in terms of cloudiness to latitude. This makes some sense because any point in the world could be covered by clouds or storms at any point in time. This also shows there tends to be more clouds near the equator which makes sense because of tropical storms in a given season.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df.plot(kind='scatter', x='Lat', y='Wind Speed',
                 title='Latitude vs. Wind Speed (m/s)', xlabel='Latitude', ylabel='Wind Speed (m/s)', marker='x', color='steelblue')
n_lat_wind_reg = linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])

plt.plot(northern_hemi_df['Lat'], n_lat_wind_reg, color='r')
plt.show()

correlation = round(st.pearsonr(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: 0.14

# %%
# Southern Hemisphere
southern_hemi_df.plot(kind='scatter', x='Lat', y='Wind Speed',
                 title='Latitude vs. Wind Speed (m/s)', xlabel='Latitude', ylabel='Wind Speed (m/s)', marker='x', color='steelblue')
s_lat_wind_reg = linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])

plt.plot(southern_hemi_df['Lat'], s_lat_wind_reg, color='r')
plt.show()

correlation = round(st.pearsonr(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])[0],2)
print(f"There was a correlation value of: {correlation}")
# Out:
# There was a correlation value of: -0.17

# %% [markdown]
# **Discussion about the linear relationship:** There is very weak correlation here. This makes sense as wind speeds do not tend to be specific to regions. However, the correlation could speak to being closer to the equator as wind speeds may be more consistent and related to tropical storms in a given season.
